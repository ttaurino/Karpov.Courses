# %%
import pandas as pd

# %%
# avocado_mea = pd.read_csv("https://stepik.org/media/attachments/lesson/362453/avocado_mean.csv", index_col=0, squeeze=True, parse_dates=['Date'])
avocado_mean = pd.read_csv('/mnt/HC_Volume_18315164/home-jupyter/jupyter-s-bykov/lesson_6/avocado_mean.csv', index_col=0, squeeze=True, parse_dates=['Date'])
avocado_mean.head()
# Out:
# Date
# 2015-01-04    1.301296
# 2015-01-11    1.370648
# 2015-01-18    1.391111
# 2015-01-25    1.397130
# 2015-02-01    1.247037
# Name: AveragePrice, dtype: float64

# %%
# шаг 2
avocado_mean.rolling(window=3).mean().max().round(2)
# Out:
# 1.85

# %%
# шаг 5
avocado_ewm = avocado_mean.ewm(span=2).mean()

# %%
# шаг 6
avocado = pd.read_csv('/mnt/HC_Volume_18315164/home-jupyter/jupyter-s-bykov/lesson_6/avocado_full.csv', index_col=0)
org_r = avocado.query("type == 'organic' and region == 'Chicago'").AveragePrice.rolling(window=4).mean().round(3).fillna(0)
org_e = avocado.query("type == 'organic' and region == 'Chicago'").AveragePrice.ewm(span=4).mean().round(3)

# %%
org_r.plot()

# %%
org_e.plot()

# %%
org_r['2016-08-21']
# Out:
# 2.102

# %%
org_e['2016-08-21']
# Out:
# 2.062

# %%
org_r['2017-02-19']
# Out:
# 1.532

# %%
org_e['2017-02-19']
# Out:
# 1.562

# %%
# шаг 7
# df = pd.read_csv('/mnt/HC_Volume_18315164/home-jupyter/jupyter-s-bykov/lesson_6/delays.csv')
df.delay = df['delay'].str.replace('-', '')
df.delay = pd.to_timedelta(df.delay)
